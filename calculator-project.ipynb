# %%
import random as rnd 
import time

# %%
def topla(liste):
    print("Sayıların toplami: ")
    print(sum(liste))

def sayilari_goster(liste):
    print("Generate edilen sayilar: ")
    print(liste)

def buyukten_kucuge(liste):
    print("Sayılar: ")
    print(liste)
    list.sort(reverse=True)
    print("Büyükten kücüge hali: ")
    print(liste)
    
def kucukten_buyuge(liste):
    print("Sayılar: ")
    print(liste)
    liste.sort()
    print("Küçükten büyüğe hali: ")
    print(liste)
    
def ortalama(liste):
    toplam = sum(liste)
    uzunluk = len(liste)
    average = toplam/uzunluk
    print("Sayıların ortalamasi: ")
    print(average)


while True: 
    
    sayi = int(input("Kac sayi uretmek istiyorsun: "))
    son_Deger = int(input("son limit kac olsun: "))

    list = []

    for i in range(sayi):
        a = rnd.randint(0, son_Deger)
        list.append(a)
    
    print("""HİZMETLERİMİZ \n[1] SAYILARI GOSTER \n[2] SAYILARI TOPLA \n[3] KUCUKTEN BUYUGE SIRALA \n[4] BUYUKTEN KUCUGE SIRALA \n[5] SAYILARIN ORTALAMASINI BUL \n[0] UYGULAMADAN CIK""")

    secilen_deger = int(input("Hangi işlemi yapmak istiyorsun: ")) 

    while (secilen_deger != 0):
    
        if secilen_deger == 1:
            sayilari_goster(list)
            
    
        elif secilen_deger == 2: 
    
            topla(list)
            
    
        elif secilen_deger == 3:

            kucukten_buyuge(list)

        elif secilen_deger == 4:
    
            buyukten_kucuge(list)
    
        elif secilen_deger == 5:
            sayilari_goster(list)
            ortalama(list)
    
        
        break
      
    if secilen_deger == 0:
        print("Programdan çıkılıyor..")
        time.sleep(2)
        print("Programdan çıkıldı.")
        break
# Out:
# Kac sayi uretmek istiyorsun: 10
# son limit kac olsun: 33
# HİZMETLERİMİZ
# [1] SAYILARI GOSTER
# [2] SAYILARI TOPLA
# [3] KUCUKTEN BUYUGE SIRALA
# [4] BUYUKTEN KUCUGE SIRALA
# [5] SAYILARIN ORTALAMASINI BUL
# [0] UYGULAMADAN CIK
# Hangi işlemi yapmak istiyorsun: 2
# Sayıların toplami:
# 190
# Kac sayi uretmek istiyorsun: 22
# son limit kac olsun: 134
# HİZMETLERİMİZ
# [1] SAYILARI GOSTER
# [2] SAYILARI TOPLA
# [3] KUCUKTEN BUYUGE SIRALA
# [4] BUYUKTEN KUCUGE SIRALA
# [5] SAYILARIN ORTALAMASINI BUL
# [0] UYGULAMADAN CIK
# Hangi işlemi yapmak istiyorsun: 1
# Generate edilen sayilar:
# [42, 35, 0, 90, 51, 37, 36, 53, 39, 23, 62, 66, 89, 47, 63, 103, 30, 113, 106, 112, 133, 36]
# Kac sayi uretmek istiyorsun: 5
# son limit kac olsun: 22
# HİZMETLERİMİZ
# [1] SAYILARI GOSTER
# [2] SAYILARI TOPLA
# [3] KUCUKTEN BUYUGE SIRALA
# [4] BUYUKTEN KUCUGE SIRALA
# [5] SAYILARIN ORTALAMASINI BUL
# [0] UYGULAMADAN CIK
# Hangi işlemi yapmak istiyorsun: 5
# Generate edilen sayilar:
# [0, 4, 20, 9, 8]
# Sayıların ortalamasi:
# 8.2
# Kac sayi uretmek istiyorsun: 23
# son limit kac olsun: 23
# HİZMETLERİMİZ
# [1] SAYILARI GOSTER
# [2] SAYILARI TOPLA
# [3] KUCUKTEN BUYUGE SIRALA
# [4] BUYUKTEN KUCUGE SIRALA
# [5] SAYILARIN ORTALAMASINI BUL
# [0] UYGULAMADAN CIK
# Hangi işlemi yapmak istiyorsun: 3
# Sayılar:
# [18, 2, 2, 0, 18, 23, 12, 2, 6, 15, 17, 2, 10, 4, 16, 3, 4, 19, 7, 16, 14, 15, 15]
# Küçükten büyüğe hali:
# [0, 2, 2, 2, 2, 3, 4, 4, 6, 7, 10, 12, 14, 15, 15, 15, 16, 16, 17, 18, 18, 19, 23]
